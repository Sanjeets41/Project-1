# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv")

# %%
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv")

# %%
df1.head()
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
np.array(df.index)
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
np.array(df1.index)
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
df.rename(columns={'Indicator': 'Indicator_id'}).head(5)
# Out:
#                         Indicator_id PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df.rename(columns={'PUBLISH STATES': 'Publication status'})
df.rename(columns={'WHO region': 'WHO Region'}).head(5)
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df.sort_values('Year',inplace=True)

# %%
df.head()
# Out:
#                               Indicator PUBLISH STATES  Year WHO region  \
# 0      Life expectancy at birth (years)      Published  1990     Europe
# 1270   Life expectancy at birth (years)      Published  1990     Europe
# 3193   Life expectancy at birth (years)      Published  1990     Europe
# 3194   Life expectancy at birth (years)      Published  1990     Europe
# 3197  Life expectancy at age 60 (years)      Published  1990     Europe
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
# 3197     Lower-middle-income  Republic of Moldova        Male             15
#
#       Numeric  Low  High  Comments
# ...

# %%
df.sort_values(['Country','Year'] ,ascending=True,inplace=True)
df.sort_values(by=['WHO region','PUBLISH STATES','Indicator'],ascending=[True,True,False],inplace=True)
df.drop_duplicates(keep="first",inplace=True)
df[["Indicator","Country","Year","WHO region","PUBLISH STATES"]].head()
# Out:
#                              Indicator  Country  Year WHO region  \
# 2510  Life expectancy at birth (years)  Algeria  1990     Africa
# 2145  Life expectancy at birth (years)  Algeria  1990     Africa
# 4358  Life expectancy at birth (years)  Algeria  1990     Africa
# 3968  Life expectancy at birth (years)  Algeria  2000     Africa
# 3969  Life expectancy at birth (years)  Algeria  2000     Africa
#
#      PUBLISH STATES
# 2510      Published
# 2145      Published
# 4358      Published
# 3968      Published
# 3969      Published

# %%
col="Country"
df=pd.concat([df[col],df.drop(col,axis=1)],axis=1)
df.head()
# Out:
#       Country                         Indicator PUBLISH STATES  Year  \
# 2510  Algeria  Life expectancy at birth (years)      Published  1990
# 2145  Algeria  Life expectancy at birth (years)      Published  1990
# 4358  Algeria  Life expectancy at birth (years)      Published  1990
# 3968  Algeria  Life expectancy at birth (years)      Published  2000
# 3969  Algeria  Life expectancy at birth (years)      Published  2000
#
#      WHO region World Bank income group         Sex  Display Value  Numeric  \
# 2510     Africa     Upper-middle-income        Male             66     66.0
# 2145     Africa     Upper-middle-income  Both sexes             68     68.0
# 4358     Africa     Upper-middle-income      Female             69     69.0
# 3968     Africa     Upper-middle-income        Male             68     68.0
# 3969     Africa     Upper-middle-income      Female             71     71.0
#
#       Low  High  Comments
# 2510  NaN   NaN       NaN
# 2145  NaN   NaN       NaN
# ...

# %% [markdown]
# 1. Get the column array as a variable

# %%
df.rename(columns={'WHO region': 'WHO_region'},inplace=True)
np.array(df.WHO_region)
# Out:
# array(['Africa', 'Africa', 'Africa', ..., 'Western Pacific',
#        'Western Pacific', 'Western Pacific'], dtype=object)

# %% [markdown]
# 2 Get the subset row 11,24,37

# %%
df.iloc[[11,24,37],]
# Out:
#            Country                         Indicator PUBLISH STATES  Year  \
# 1515        Angola  Life expectancy at birth (years)      Published  1990
# 560          Benin  Life expectancy at birth (years)      Published  2012
# 1800  Burkina Faso  Life expectancy at birth (years)      Published  1990
#
#      WHO_region World Bank income group         Sex  Display Value  Numeric  \
# 1515     Africa     Lower-middle-income        Male             41     41.0
# 560      Africa              Low-income        Male             57     57.0
# 1800     Africa              Low-income  Both sexes             50     50.0
#
#       Low  High  Comments
# 1515  NaN   NaN       NaN
# 560   NaN   NaN       NaN
# 1800  NaN   NaN       NaN

# %% [markdown]
# Get the subset rows excluding 5,12,23 and 56

# %%
bad_df=df.index.isin([5,12,23,56])
df[~bad_df]
# Out:
#               Country                                        Indicator  \
# 2510          Algeria                 Life expectancy at birth (years)
# 2145          Algeria                 Life expectancy at birth (years)
# 4358          Algeria                 Life expectancy at birth (years)
# 3968          Algeria                 Life expectancy at birth (years)
# 3969          Algeria                 Life expectancy at birth (years)
# 2146          Algeria                 Life expectancy at birth (years)
# 4357          Algeria                 Life expectancy at birth (years)
# 3584          Algeria                 Life expectancy at birth (years)
# 3583          Algeria                 Life expectancy at birth (years)
# 3108           Angola                 Life expectancy at birth (years)
# 1084           Angola                 Life expectancy at birth (years)
# 1515           Angola                 Life expectancy at birth (years)
# ...

# %%
users=pd.read_csv("https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv")
sessions=pd.read_csv("https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv")
products=pd.read_csv("https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv")
transactions=pd.read_csv("https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv")
users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
products.head()
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %% [markdown]
# 1 Join users to transactions,keeping all rows from transactions and only matching rows from users(left join)

# %%
from pandasql import sqldf
pysqldf = lambda q:sqldf(q,globals())
pysqldf("SELECT transactions.TransactionID,transactions.TransactionDate,transactions.UserID,transactions.ProductID,transactions.Quantity,users.User,users.Gender,users.Registered,users.Cancelled FROM transactions LEFT JOIN users ON transactions.UserID = users.UserID ;")
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1      None
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3      None
# 8              9      2015-04-24     7.0          4         3      None
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0    None        None        None
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21        None
# ...

# %% [markdown]
# Which transactions has a UserID not in Users

# %%
transactions[~transactions['UserID'].isin(users['UserID'])]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %% [markdown]
# Join Users to transactions , keeping only rows from transactions and users that match via UserID(inner join)

# %%
pysqldf("select transactions.TransactionID,transactions.TransactionDate,transactions.UserID,transactions.ProductID,transactions.Quantity,users.User,users.Gender,users.Registered,users.Cancelled from transactions INNER JOIN users on transactions.UserID = users.UserID ;")
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              4      2012-08-26     1.0          2         3   Charles
# 3              5      2013-06-06     2.0          4         1     Pedro
# 4              6      2013-12-23     2.0          5         6     Pedro
# 5              7      2013-12-30     3.0          4         1  Caroline
# 6             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2    male  2012-12-21        None
# 3    male  2010-08-01  2010-08-08
# 4    male  2010-08-01  2010-08-08
# 5  female  2012-10-23  2016-06-07
# 6  female  2012-10-23  2016-06-07

# %% [markdown]
# Join Users to transactions,displaying all matching rows AND all not matching rows

# %%
result = pd.merge(users,
                 transactions,
                 on='UserID', 
                 how='outer', 
                 )

result
# Out:
#     UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0      1.0   Charles    male  2012-12-21         NaN            4.0
# 1      2.0     Pedro    male  2010-08-01  2010-08-08            5.0
# 2      2.0     Pedro    male  2010-08-01  2010-08-08            6.0
# 3      3.0  Caroline  female  2012-10-23  2016-06-07            2.0
# 4      3.0  Caroline  female  2012-10-23  2016-06-07            3.0
# 5      3.0  Caroline  female  2012-10-23  2016-06-07            7.0
# 6      3.0  Caroline  female  2012-10-23  2016-06-07           10.0
# 7      4.0   Brielle  female  2013-07-17         NaN            NaN
# 8      5.0  Benjamin    male  2010-11-25         NaN            NaN
# 9      7.0       NaN     NaN         NaN         NaN            1.0
# 10     7.0       NaN     NaN         NaN         NaN            9.0
# 11     NaN       NaN     NaN         NaN         NaN            8.0
#
#    TransactionDate  ProductID  Quantity
# 0       2012-08-26        2.0       3.0
# ...

# %% [markdown]
# Determine which sessions occured on the same day each user registered.

# %%
pysqldf("select users.UserID,users.User,users.Gender,users.Registered,users.Cancelled, sessions.SessionID,sessions.SessionDate from sessions join users where sessions.SessionDate=users.Registered  ")
# Out:
#    UserID      User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       2     Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 1       5  Benjamin    male  2010-11-25        None          3  2010-11-25
# 2       3  Caroline  female  2012-10-23  2016-06-07          6  2012-10-23
# 3       1   Charles    male  2012-12-21        None          7  2012-12-21
# 4       4   Brielle  female  2013-07-17        None          9  2013-07-17

# %% [markdown]
# Build a dataset with every possible (userID,ProductID) pair(cross join)

# %%
pysqldf("select users.UserID,products.ProductID from users,products")
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %% [markdown]
# Determine how much quantity of each product was purchased by each users

# %%
pysqldf("select transactions.UserID,transactions.ProductID,transactions.Quantity from transactions order by UserID ")
# Out:
#    UserID  ProductID  Quantity
# 0     NaN          2         3
# 1     1.0          2         3
# 2     2.0          4         1
# 3     2.0          5         6
# 4     3.0          4         1
# 5     3.0          3         1
# 6     3.0          4         1
# 7     3.0          4         4
# 8     7.0          2         1
# 9     7.0          4         3

# %% [markdown]
# For each users, get each possible pair of pair transactions(TransactionID1,TransactionID2)

# %%
pd.merge(transactions, transactions, on='UserID')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %% [markdown]
# Join each user to his/her first occuring transaction in the transactions table

# %%
pd.merge(users, transactions.groupby('UserID').first().reset_index(), how='left', on='UserID')
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 3       4   Brielle  female  2013-07-17         NaN            NaN
# 4       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %%
transactions.groupby('UserID').first().reset_index()
# Out:
#    UserID  TransactionID TransactionDate  ProductID  Quantity
# 0     1.0              4      2012-08-26          2         3
# 1     2.0              5      2013-06-06          4         1
# 2     3.0              2      2011-05-26          4         1
# 3     7.0              1      2010-08-21          2         1

# %% [markdown]
# Test to see if we can drop columns

# %%
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %%
transactions.drop('Quantity', axis=1, inplace=True)
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID
# 0              1      2010-08-21     7.0          2
# 1              2      2011-05-26     3.0          4
# 2              3      2011-06-16     3.0          3
# 3              4      2012-08-26     1.0          2
# 4              5      2013-06-06     2.0          4
